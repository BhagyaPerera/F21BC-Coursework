# %% [markdown]
# ### **Task 4- Train and Evaluation**

# %% [markdown]
# #### **Project Path and imports**

# %%
import sys
from pathlib import Path
from src.train.pipeline import run_pipeline
from src.ann.config import ANNConfig
from src.pso.config import PSOConfig

# project root = parent of "notebooks"
PROJECT_ROOT = Path(__file__).resolve().parents[1] if "__file__" in globals() else Path.cwd().parents[0]

# Make sure root is on sys.path so we can import train, pso, etc.
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT
# Out:
# WindowsPath('C:/university/BC/F21BC-Coursework/src/notebooks')

# %% [markdown]
# #### **ANN Configs**

# %%
# ANN CONFIG — baseline
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 8,  "activation": "relu"},
    ],
    output_dim=1,
)

# %% [markdown]
# #### **PSO Configs**

# %%
pso_config = PSOConfig(
    swarm_size=80,          # Large swarm → better global exploration
    iterations=2000,         # Enough time for convergence
    alpha=0.7,              # Balanced inertia
    beta=1.5,               # Cognitive pull (personal best)
    gamma=1.5,              # Social pull (informants)
    delta=0.0,              # Avoids unstable attraction to global best
    e=1.0,                  # Step size multiplier
    bounds=(-10.0, 10.0),   # Larger weight search space → better minima
    v_clamp=(-3.0, 3.0),    # Prevents overshooting while maintaining velocity
    k_informants=3,         # Light, local collaboration
    topology="ring",        # BEST topology for ANN optimisation
    ring_radius=1,          # Small neighbourhood → stable convergence
    boundary_mode="reflect",# Avoid particle dead zones (better exploration)
    rewire_every=None,      # Stable topology
    seed=None,              # Let PSO randomness help explore more
    minimize=True           # We minimise MAE
)

# %% [markdown]
# #### **Train and Test evaluation**

# %%
# Run training pipeline
run_pipeline(ann_config, pso_config,runs=10)
# Out:
# ======== EXPERIMENTAL PIPELINE (10 RUNS) ========
#
#  Run 1/10
# [PSO] iter 1/2000 gbest=18.369089
# [PSO] iter 201/2000 gbest=7.510208
# [PSO] iter 401/2000 gbest=6.705090
# [PSO] iter 601/2000 gbest=6.451215
# [PSO] iter 801/2000 gbest=6.257118
# [PSO] iter 1001/2000 gbest=6.177341
# [PSO] iter 1201/2000 gbest=6.109114
# [PSO] iter 1401/2000 gbest=5.916263
# [PSO] iter 1601/2000 gbest=5.828378
# [PSO] iter 1801/2000 gbest=5.755903
# [PSO] iter 2000/2000 gbest=5.712073
#    gBest=5.7121 | Train MAE=5.7121 | Test MAE=5.7196
#
#  Run 2/10
# [PSO] iter 1/2000 gbest=16.833410
# [PSO] iter 201/2000 gbest=7.028685
# [PSO] iter 401/2000 gbest=6.455657
# [PSO] iter 601/2000 gbest=6.074062
# [PSO] iter 801/2000 gbest=5.867790
# [PSO] iter 1001/2000 gbest=5.757616
# [PSO] iter 1201/2000 gbest=5.529087
# [PSO] iter 1401/2000 gbest=5.298309
# [PSO] iter 1601/2000 gbest=5.240423
# [PSO] iter 1801/2000 gbest=5.212190
# [PSO] iter 2000/2000 gbest=5.199472
#    gBest=5.1995 | Train MAE=5.1995 | Test MAE=5.2527
#
#  Run 3/10
# [PSO] iter 1/2000 gbest=15.638561
# [PSO] iter 201/2000 gbest=7.019171
# [PSO] iter 401/2000 gbest=6.377538
# [PSO] iter 601/2000 gbest=6.033552
# [PSO] iter 801/2000 gbest=5.690164
# [PSO] iter 1001/2000 gbest=5.523529
# [PSO] iter 1201/2000 gbest=5.523385
# [PSO] iter 1401/2000 gbest=5.465812
# [PSO] iter 1601/2000 gbest=5.361698
# [PSO] iter 1801/2000 gbest=5.333279
# [PSO] iter 2000/2000 gbest=5.315876
#    gBest=5.3159 | Train MAE=5.3159 | Test MAE=5.4341
#
#  Run 4/10
# [PSO] iter 1/2000 gbest=17.048219
# [PSO] iter 201/2000 gbest=7.366000
# [PSO] iter 401/2000 gbest=6.871675
# [PSO] iter 601/2000 gbest=6.647697
# [PSO] iter 801/2000 gbest=6.567048
# [PSO] iter 1001/2000 gbest=6.535525
# [PSO] iter 1201/2000 gbest=6.505470
# [PSO] iter 1401/2000 gbest=6.489536
# [PSO] iter 1601/2000 gbest=6.455783
# [PSO] iter 1801/2000 gbest=6.369518
# [PSO] iter 2000/2000 gbest=6.200389
#    gBest=6.2004 | Train MAE=6.2004 | Test MAE=6.9767
#
#  Run 5/10
# [PSO] iter 1/2000 gbest=14.579075
# [PSO] iter 201/2000 gbest=7.053783
# [PSO] iter 401/2000 gbest=6.599752
# [PSO] iter 601/2000 gbest=6.294685
# [PSO] iter 801/2000 gbest=6.159686
# [PSO] iter 1001/2000 gbest=6.120672
# [PSO] iter 1201/2000 gbest=6.085903
# [PSO] iter 1401/2000 gbest=6.065913
# [PSO] iter 1601/2000 gbest=6.040999
# [PSO] iter 1801/2000 gbest=5.946495
# [PSO] iter 2000/2000 gbest=5.897148
#    gBest=5.8971 | Train MAE=5.8971 | Test MAE=5.9942
#
#  Run 6/10
# [PSO] iter 1/2000 gbest=21.271217
# [PSO] iter 201/2000 gbest=7.182826
# [PSO] iter 401/2000 gbest=6.274981
# [PSO] iter 601/2000 gbest=6.119696
# [PSO] iter 801/2000 gbest=6.041647
# [PSO] iter 1001/2000 gbest=5.752044
# [PSO] iter 1201/2000 gbest=5.686758
# [PSO] iter 1401/2000 gbest=5.642077
# [PSO] iter 1601/2000 gbest=5.627075
# [PSO] iter 1801/2000 gbest=5.596477
# [PSO] iter 2000/2000 gbest=5.566796
#    gBest=5.5668 | Train MAE=5.5668 | Test MAE=5.7793
#
#  Run 7/10
# [PSO] iter 1/2000 gbest=18.458053
# [PSO] iter 201/2000 gbest=7.604099
# [PSO] iter 401/2000 gbest=6.369594
# [PSO] iter 601/2000 gbest=6.213105
# [PSO] iter 801/2000 gbest=6.152912
# [PSO] iter 1001/2000 gbest=6.096872
# [PSO] iter 1201/2000 gbest=6.019493
# [PSO] iter 1401/2000 gbest=5.954664
# [PSO] iter 1601/2000 gbest=5.918586
# [PSO] iter 1801/2000 gbest=5.902452
# [PSO] iter 2000/2000 gbest=5.883774
#    gBest=5.8838 | Train MAE=5.8838 | Test MAE=5.9607
#
#  Run 8/10
# [PSO] iter 1/2000 gbest=17.072978
# [PSO] iter 201/2000 gbest=6.885075
# [PSO] iter 401/2000 gbest=6.315963
# [PSO] iter 601/2000 gbest=6.086755
# [PSO] iter 801/2000 gbest=5.904543
# [PSO] iter 1001/2000 gbest=5.743678
# [PSO] iter 1201/2000 gbest=5.695426
# [PSO] iter 1401/2000 gbest=5.647691
# [PSO] iter 1601/2000 gbest=5.585587
# [PSO] iter 1801/2000 gbest=5.527507
# [PSO] iter 2000/2000 gbest=5.502298
#    gBest=5.5023 | Train MAE=5.5023 | Test MAE=6.0780
#
#  Run 9/10
# [PSO] iter 1/2000 gbest=23.845264
# [PSO] iter 201/2000 gbest=7.306808
# [PSO] iter 401/2000 gbest=7.112974
# [PSO] iter 601/2000 gbest=6.782901
# [PSO] iter 801/2000 gbest=6.659310
# [PSO] iter 1001/2000 gbest=6.372372
# [PSO] iter 1201/2000 gbest=6.335823
# [PSO] iter 1401/2000 gbest=6.192182
# [PSO] iter 1601/2000 gbest=6.068230
# [PSO] iter 1801/2000 gbest=6.000930
# [PSO] iter 2000/2000 gbest=5.909521
#    gBest=5.9095 | Train MAE=5.9095 | Test MAE=6.2346
#
#  Run 10/10
# [PSO] iter 1/2000 gbest=20.463309
# [PSO] iter 201/2000 gbest=7.245337
# [PSO] iter 401/2000 gbest=6.664693
# [PSO] iter 601/2000 gbest=6.301866
# [PSO] iter 801/2000 gbest=6.044246
# [PSO] iter 1001/2000 gbest=5.986995
# [PSO] iter 1201/2000 gbest=5.978421
# [PSO] iter 1401/2000 gbest=5.944944
# [PSO] iter 1601/2000 gbest=5.901625
# [PSO] iter 1801/2000 gbest=5.883258
# [PSO] iter 2000/2000 gbest=5.860388
#    gBest=5.8604 | Train MAE=5.8604 | Test MAE=6.0345
#
# ======== EXPERIMENT SUMMARY (Mean ± SD) ========
# Number of Runs:   10
# ANN Architecture: 8(relu)
# PSO Config:       swarm=80, iter=2000, αlpha=0.7, beta=1.5, gamma=1.5, bounds=(-10.0, 10.0)
# Average gBest:    5.7048 ± 0.2911
# Average Train MAE:5.7048 ± 0.2911
# Average Test MAE: 5.9464 ± 0.4467
# ===================================================
# C:\university\BC\F21BC-Coursework\src\train\pipeline.py:170: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(rect=[1, 0, 1, 0.94])
# Generating averaged plots across runs...
# visualization completed.

# %% [markdown]
# #### **Results & Discussion**
#
#
# This is our initial experiment used an ANN with two hidden layers which contains 16, 8 neurons with RELU activation and PSO configuration of 40 particles and 400 iterations. The model achieved a training MAE(mean absolute error) of 6.6270 and testing MAE 7.2031 indicating good generalisation with minimal overfitting. The PSO convergence curve showed a steep improvement in the early iterations followed by gradual stabilisation, suggesting effective exploration and convergence toward optimal network parameters. The small gap between training and testing MAE confirms that the network successfully captured the non-linear relationships within the concrete strength dataset. Overall, this result establishes a strong baseline, demonstrating that PSO can efficiently optimise ANN weights and biases for regression problems without gradient-based learning, while providing a stable and interpretable convergence pattern.
