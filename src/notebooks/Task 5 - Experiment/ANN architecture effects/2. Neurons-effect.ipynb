# %% [markdown]
# ### **Experiment with different ANN-Neuron size**

# %% [markdown]
# #### **Project Path and imports**

# %%
import sys
from pathlib import Path
from src.train.pipeline import run_pipeline
from src.ann.config import ANNConfig
from src.pso.config import PSOConfig

# project root = parent of "notebooks"
PROJECT_ROOT = Path(__file__).resolve().parents[1] if "__file__" in globals() else Path.cwd().parents[0]

# Make sure root is on sys.path so we can import train, pso, etc.
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %% [markdown]
# #### **PSO Configs- Static**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=40,
    iterations=400,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %% [markdown]
# #### **ANN -8 Neurons**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 8,  "activation": "relu"},
        {"units": 8,  "activation": "relu"},
        {"units": 8,  "activation": "relu"},
    ],
    output_dim=1,
)

# %%
# Run training pipeline
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **ANN-16 Neurons**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 16,  "activation": "relu"},
        {"units": 16,  "activation": "relu"},
        {"units": 16,  "activation": "relu"},
    ],
    output_dim=1,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **ANN - 32 Neurons**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 32,  "activation": "relu"}, #Hidden Layer 1
        {"units": 32,  "activation": "relu"}, #Hidden Layer 2
        {"units": 32,  "activation": "relu"}, #Hidden Layer 3
    ],
    output_dim=1,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 run_pipeline(ann_config, pso_config,runs=10)
#
# File C:\university\BC\F21BC-Coursework\src\train\pipeline.py:102, in run_pipeline(ann_config, pso_config, runs)
#     100 for i in range(runs):
#     101     print(f"\n Run {i+1}/{runs}")
# --> 102     result = run_single_training(ann_config, pso_config, return_history_only=False)
#     103     results.append(result)
#     104     histories.append(result["history"])
#
# File C:\university\BC\F21BC-Coursework\src\train\pipeline.py:59, in run_single_training(ann_config, pso_config, return_history_only)
#      56     x_test_s = x_test
#      58 # 4) train (PSO + ANN)
# ---> 59 net, best_fit, history = train_with_pso(x_train_s,y_train,ann_config,pso_config)
#      61 if return_history_only:
#      62     return history  # just the PSO curve
#
# File C:\university\BC\F21BC-Coursework\src\train\trainer.py:21, in train_with_pso(x_train, y_train, ann_config, pso_config)
#      15 def train_with_pso(
#      16     x_train: Sequence[Sequence[float]],
#      17     y_train: Sequence[float],
#      18     ann_config: ANNConfig,
#      19     pso_config: PSOConfig,
#      20 ) -> Tuple[Network, float, List[float]]:
# ---> 21     net, best_fit, history = train_ann_with_pso(x_train, y_train,pso_config,ann_config)
#      22     return net, best_fit, history
#
# File C:\university\BC\F21BC-Coursework\src\ann_pso\ann_pso.py:100, in train_ann_with_pso(x_train, y_train, pso_config, ann_config)
#      93 pso = PSO(
#      94     dimension=dim,
#      95     fitness_fn=objective,
#      96     config=cfg,
#      97 )
#      99 # 6) run optimisation
# --> 100 best_position, best_fitness,history = pso.run(verbose=True)
#     102 # 7) load the best weights into the ANN so caller can use it
#     103 net.set_parameters(best_position)
#
# File C:\university\BC\F21BC-Coursework\src\pso\core.py:105, in PSO.run(self, verbose)
#     103     f = (math.inf if self.config.minimize else -math.inf) if out else self.fitness_fn(x)
#     104 else:
# --> 105     f = self.fitness_fn(x)  # lines 12–13: AssessFitness(x)
#     107 # line 14: update personal best x*
#     108 if self.is_better(f, self.pbest_val[j]):
#
# File C:\university\BC\F21BC-Coursework\src\ann_pso\ann_pso.py:47, in make_ann_objective.<locals>.objective(position)
#      45 predictions: List[float] = []
#      46 for x_input in x:
# ---> 47     out = network.forward_algorithm(x_input)
#      48     predictions.append(out[0])        # take the single output
#      50 # 3) lower loss = better particle
#
# File C:\university\BC\F21BC-Coursework\src\ann\network.py:24, in Network.forward_algorithm(self, x)
#      22 output = list(x)
#      23 for layer in self.layers:
# ---> 24     output = layer.forward_algorithm(output)
#      25 return output
#
# File C:\university\BC\F21BC-Coursework\src\ann\layer.py:73, in Dense.forward_algorithm(self, input_x)
#      71 output_y: List[float] = []                                                                    #create an empty list output
#      72 for i in range(self.output_dimension):
# ---> 73     z = sum(weight*xj for weight, xj in zip(self.weights[i], input_x)) + self.bias[i]
#      74     output_y.append(self.activation(z))                                                      #calculate output=f(w.x+b) for each input and append to output_y list.
#      75 return output_y
#
# File C:\university\BC\F21BC-Coursework\src\ann\layer.py:73, in <genexpr>(.0)
#      71 output_y: List[float] = []                                                                    #create an empty list output
#      72 for i in range(self.output_dimension):
# ---> 73     z = sum(weight*xj for weight, xj in zip(self.weights[i], input_x)) + self.bias[i]
#      74     output_y.append(self.activation(z))                                                      #calculate output=f(w.x+b) for each input and append to output_y list.
#      75 return output_y
#
# KeyboardInterrupt:

# %% [markdown]
# #### **ANN - 64 Neurons**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 64,  "activation": "relu"}, #Hidden Layer 1
        {"units": 64,  "activation": "relu"}, #Hidden Layer 2
        {"units": 64,  "activation": "relu"}, #Hidden Layer 3
    ],
    output_dim=1,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **Results & Discussion**
#
#
# This is our initial experiment used an ANN with two hidden layers which contains 16, 8 neurons with RELU activation and PSO configuration of 40 particles and 400 iterations. The model achieved a training MAE(mean absolute error) of 6.6270 and testing MAE 7.2031 indicating good generalisation with minimal overfitting. The PSO convergence curve showed a steep improvement in the early iterations followed by gradual stabilisation, suggesting effective exploration and convergence toward optimal network parameters. The small gap between training and testing MAE confirms that the network successfully captured the non-linear relationships within the concrete strength dataset. Overall, this result establishes a strong baseline, demonstrating that PSO can efficiently optimise ANN weights and biases for regression problems without gradient-based learning, while providing a stable and interpretable convergence pattern.
