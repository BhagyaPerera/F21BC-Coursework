# %% [markdown]
# ### **Experiment with different ANN-Layer size**

# %% [markdown]
# #### **Project Path and imports**

# %%
import sys
from pathlib import Path
from src.train.pipeline import run_pipeline
from src.ann.config import ANNConfig
from src.pso.config import PSOConfig

# project root = parent of "notebooks"
PROJECT_ROOT = Path(__file__).resolve().parents[1] if "__file__" in globals() else Path.cwd().parents[0]

# Make sure root is on sys.path so we can import train, pso, etc.
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT
# Out:
# WindowsPath('C:/university/BC/F21BC-Coursework/src/notebooks/Task 5 - Experiment')

# %% [markdown]
# #### **PSO Configs- Static**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=40,
    iterations=200,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %% [markdown]
# #### **ANN -1 Hidden Layer**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 8,  "activation": "relu"},
    ],
    output_dim=1,
)

# %% [markdown]
# ##### **Train and Test evaluation**

# %%
# Run training pipeline
run_pipeline(ann_config, pso_config,runs=10)
# Out:
# ======== EXPERIMENTAL PIPELINE (10 RUNS) ========
#
#  Run 1/10
# [PSO] iter 1/200 gbest=16.216891
# [PSO] iter 21/200 gbest=9.194859
# [PSO] iter 41/200 gbest=8.425698
# [PSO] iter 61/200 gbest=8.193206
# [PSO] iter 81/200 gbest=7.994628
# [PSO] iter 101/200 gbest=7.677628
# [PSO] iter 121/200 gbest=7.653186
# [PSO] iter 141/200 gbest=7.604306
# [PSO] iter 161/200 gbest=7.589348
# [PSO] iter 181/200 gbest=7.566645
# [PSO] iter 200/200 gbest=7.478609
#    gBest=7.4786 | Train MAE=7.4786 | Test MAE=7.8529
#
#  Run 2/10
# [PSO] iter 1/200 gbest=13.653944
# [PSO] iter 21/200 gbest=9.633516
# [PSO] iter 41/200 gbest=8.586076
# [PSO] iter 61/200 gbest=8.208046
# [PSO] iter 81/200 gbest=8.122607
# [PSO] iter 101/200 gbest=8.054000
# [PSO] iter 121/200 gbest=7.994160
# [PSO] iter 141/200 gbest=7.817004
# [PSO] iter 161/200 gbest=7.702015
# [PSO] iter 181/200 gbest=7.504935
# [PSO] iter 200/200 gbest=7.403870
#    gBest=7.4039 | Train MAE=7.4039 | Test MAE=7.8176
#
#  Run 3/10
# [PSO] iter 1/200 gbest=13.553669
# [PSO] iter 21/200 gbest=9.540137
# [PSO] iter 41/200 gbest=8.714619
# [PSO] iter 61/200 gbest=8.426960
# [PSO] iter 81/200 gbest=8.228461
# [PSO] iter 101/200 gbest=8.162641
# [PSO] iter 121/200 gbest=8.003809
# [PSO] iter 141/200 gbest=7.905919
# [PSO] iter 161/200 gbest=7.782146
# [PSO] iter 181/200 gbest=7.628316
# [PSO] iter 200/200 gbest=7.550068
#    gBest=7.5501 | Train MAE=7.5501 | Test MAE=8.1635
#
#  Run 4/10
# [PSO] iter 1/200 gbest=14.957393
# [PSO] iter 21/200 gbest=9.653385
# [PSO] iter 41/200 gbest=8.714713
# [PSO] iter 61/200 gbest=8.492189
# [PSO] iter 81/200 gbest=8.128893
# [PSO] iter 101/200 gbest=8.027287
# [PSO] iter 121/200 gbest=7.924022
# [PSO] iter 141/200 gbest=7.822452
# [PSO] iter 161/200 gbest=7.701718
# [PSO] iter 181/200 gbest=7.570795
# [PSO] iter 200/200 gbest=7.494073
#    gBest=7.4941 | Train MAE=7.4941 | Test MAE=8.1693
#
#  Run 5/10
# [PSO] iter 1/200 gbest=13.291915
# [PSO] iter 21/200 gbest=9.166947
# [PSO] iter 41/200 gbest=8.409641
# [PSO] iter 61/200 gbest=8.003314
# [PSO] iter 81/200 gbest=7.836639
# [PSO] iter 101/200 gbest=7.676340
# [PSO] iter 121/200 gbest=7.673926
# [PSO] iter 141/200 gbest=7.477590
# [PSO] iter 161/200 gbest=7.453629
# [PSO] iter 181/200 gbest=7.453623
# [PSO] iter 200/200 gbest=7.453623
#    gBest=7.4536 | Train MAE=7.4536 | Test MAE=8.2027
#
#  Run 6/10
# [PSO] iter 1/200 gbest=13.646897
# [PSO] iter 21/200 gbest=9.150023
# [PSO] iter 41/200 gbest=8.367449
# [PSO] iter 61/200 gbest=7.686163
# [PSO] iter 81/200 gbest=7.510027
# [PSO] iter 101/200 gbest=7.326616
# [PSO] iter 121/200 gbest=7.241953
# [PSO] iter 141/200 gbest=7.123673
# [PSO] iter 161/200 gbest=6.976178
# [PSO] iter 181/200 gbest=6.936027
# [PSO] iter 200/200 gbest=6.908719
#    gBest=6.9087 | Train MAE=6.9087 | Test MAE=7.5602
#
#  Run 7/10
# [PSO] iter 1/200 gbest=14.781885
# [PSO] iter 21/200 gbest=9.807847
# [PSO] iter 41/200 gbest=8.733353
# [PSO] iter 61/200 gbest=8.423315
# [PSO] iter 81/200 gbest=7.934914
# [PSO] iter 101/200 gbest=7.718143
# [PSO] iter 121/200 gbest=7.678451
# [PSO] iter 141/200 gbest=7.659877
# [PSO] iter 161/200 gbest=7.659325
# [PSO] iter 181/200 gbest=7.659324
# [PSO] iter 200/200 gbest=7.659324
#    gBest=7.6593 | Train MAE=7.6593 | Test MAE=7.9962
#
#  Run 8/10
# [PSO] iter 1/200 gbest=15.878707
# [PSO] iter 21/200 gbest=9.187716
# [PSO] iter 41/200 gbest=8.953821
# [PSO] iter 61/200 gbest=8.314990
# [PSO] iter 81/200 gbest=8.177367
# [PSO] iter 101/200 gbest=8.093828
# [PSO] iter 121/200 gbest=7.981996
# [PSO] iter 141/200 gbest=7.948045
# [PSO] iter 161/200 gbest=7.884068
# [PSO] iter 181/200 gbest=7.850247
# [PSO] iter 200/200 gbest=7.634573
#    gBest=7.6346 | Train MAE=7.6346 | Test MAE=7.9702
#
#  Run 9/10
# [PSO] iter 1/200 gbest=15.254735
# [PSO] iter 21/200 gbest=9.601997
# [PSO] iter 41/200 gbest=8.329660
# [PSO] iter 61/200 gbest=8.123925
# [PSO] iter 81/200 gbest=8.048736
# [PSO] iter 101/200 gbest=7.814653
# [PSO] iter 121/200 gbest=7.709886
# [PSO] iter 141/200 gbest=7.604319
# [PSO] iter 161/200 gbest=7.545847
# [PSO] iter 181/200 gbest=7.520577
# [PSO] iter 200/200 gbest=7.400026
#    gBest=7.4000 | Train MAE=7.4000 | Test MAE=7.8983
#
#  Run 10/10
# [PSO] iter 1/200 gbest=15.878102
# [PSO] iter 21/200 gbest=8.808043
# [PSO] iter 41/200 gbest=8.219148
# [PSO] iter 61/200 gbest=8.029307
# [PSO] iter 81/200 gbest=7.906785
# [PSO] iter 101/200 gbest=7.822685
# [PSO] iter 121/200 gbest=7.767085
# [PSO] iter 141/200 gbest=7.736409
# [PSO] iter 161/200 gbest=7.678843
# [PSO] iter 181/200 gbest=7.578738
# [PSO] iter 200/200 gbest=7.531949
#    gBest=7.5319 | Train MAE=7.5319 | Test MAE=8.1299
#
# ======== EXPERIMENT SUMMARY (Mean ± SD) ========
# Number of Runs:   10
# ANN Architecture: 8(relu)
# PSO Config:       swarm=40, iter=200, αlpha=0.72, beta=1.49, gamma=1.49, bounds=(-5.0, 5.0)
# Average gBest:    7.4515 ± 0.1987
# Average Train MAE:7.4515 ± 0.1987
# Average Test MAE: 7.9761 ± 0.1916
# ===================================================
# C:\university\BC\F21BC-Coursework\src\train\pipeline.py:170: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(rect=[1, 0, 1, 0.94])
# Generating averaged plots across runs...
# visualization completed.

# %% [markdown]
# #### **ANN- 2 Hidden Layers**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 16,  "activation": "relu"}, #Hidden Layer 1
        {"units": 8,  "activation": "relu"}, #Hidden Layer 2
    ],
    output_dim=1,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)
# Out:
# ======== EXPERIMENTAL PIPELINE (10 RUNS) ========
#
#  Run 1/10
# [PSO] iter 1/200 gbest=21.103971
# [PSO] iter 21/200 gbest=11.999342
# [PSO] iter 41/200 gbest=9.232434
# [PSO] iter 61/200 gbest=8.859699
# [PSO] iter 81/200 gbest=8.478001
# [PSO] iter 101/200 gbest=8.427938
# [PSO] iter 121/200 gbest=8.354941
# [PSO] iter 141/200 gbest=8.107515
# [PSO] iter 161/200 gbest=8.077475
# [PSO] iter 181/200 gbest=7.729098
# [PSO] iter 200/200 gbest=7.533241
#    gBest=7.5332 | Train MAE=7.5332 | Test MAE=7.8375
#
#  Run 2/10
# [PSO] iter 1/200 gbest=38.094181
# [PSO] iter 21/200 gbest=12.262697
# [PSO] iter 41/200 gbest=9.964116
# [PSO] iter 61/200 gbest=9.143043
# [PSO] iter 81/200 gbest=8.680888
# [PSO] iter 101/200 gbest=8.600927
# [PSO] iter 121/200 gbest=7.972408
# [PSO] iter 141/200 gbest=7.906749
# [PSO] iter 161/200 gbest=7.906647
# [PSO] iter 181/200 gbest=7.906647
# [PSO] iter 200/200 gbest=7.906647
#    gBest=7.9066 | Train MAE=7.9066 | Test MAE=8.2989
#
#  Run 3/10
# [PSO] iter 1/200 gbest=22.290830
# [PSO] iter 21/200 gbest=10.686920
# [PSO] iter 41/200 gbest=9.328044
# [PSO] iter 61/200 gbest=8.617071
# [PSO] iter 81/200 gbest=8.609620
# [PSO] iter 101/200 gbest=8.523794
# [PSO] iter 121/200 gbest=8.107818
# [PSO] iter 141/200 gbest=7.833600
# [PSO] iter 161/200 gbest=7.791404
# [PSO] iter 181/200 gbest=7.674291
# [PSO] iter 200/200 gbest=7.674291
#    gBest=7.6743 | Train MAE=7.6743 | Test MAE=7.9475
#
#  Run 4/10
# [PSO] iter 1/200 gbest=36.085541
# [PSO] iter 21/200 gbest=10.374205
# [PSO] iter 41/200 gbest=9.679455
# [PSO] iter 61/200 gbest=8.950417
# [PSO] iter 81/200 gbest=8.753024
# [PSO] iter 101/200 gbest=8.333637
# [PSO] iter 121/200 gbest=8.269415
# [PSO] iter 141/200 gbest=8.158729
# [PSO] iter 161/200 gbest=8.081541
# [PSO] iter 181/200 gbest=7.551650
# [PSO] iter 200/200 gbest=7.497831
#    gBest=7.4978 | Train MAE=7.4978 | Test MAE=8.1543
#
#  Run 5/10
# [PSO] iter 1/200 gbest=18.673829
# [PSO] iter 21/200 gbest=10.782289
# [PSO] iter 41/200 gbest=10.239149
# [PSO] iter 61/200 gbest=9.118451
# [PSO] iter 81/200 gbest=8.615115
# [PSO] iter 101/200 gbest=8.284786
# [PSO] iter 121/200 gbest=8.203451
# [PSO] iter 141/200 gbest=8.022970
# [PSO] iter 161/200 gbest=8.011424
# [PSO] iter 181/200 gbest=7.933910
# [PSO] iter 200/200 gbest=7.930814
#    gBest=7.9308 | Train MAE=7.9308 | Test MAE=8.0814
#
#  Run 6/10
# [PSO] iter 1/200 gbest=29.770401
# [PSO] iter 21/200 gbest=12.099563
# [PSO] iter 41/200 gbest=9.812701
# [PSO] iter 61/200 gbest=9.214927
# [PSO] iter 81/200 gbest=8.558724
# [PSO] iter 101/200 gbest=8.153963
# [PSO] iter 121/200 gbest=8.078697
# [PSO] iter 141/200 gbest=8.053565
# [PSO] iter 161/200 gbest=7.737773
# [PSO] iter 181/200 gbest=7.538024
# [PSO] iter 200/200 gbest=7.410674
#    gBest=7.4107 | Train MAE=7.4107 | Test MAE=8.1426
#
#  Run 7/10
# [PSO] iter 1/200 gbest=25.898584
# [PSO] iter 21/200 gbest=10.024169
# [PSO] iter 41/200 gbest=9.234531
# [PSO] iter 61/200 gbest=8.485378
# [PSO] iter 81/200 gbest=8.342714
# [PSO] iter 101/200 gbest=8.081592
# [PSO] iter 121/200 gbest=7.937899
# [PSO] iter 141/200 gbest=7.665073
# [PSO] iter 161/200 gbest=7.562764
# [PSO] iter 181/200 gbest=7.363660
# [PSO] iter 200/200 gbest=7.329662
#    gBest=7.3297 | Train MAE=7.3297 | Test MAE=7.9484
#
#  Run 8/10
# [PSO] iter 1/200 gbest=38.966836
# [PSO] iter 21/200 gbest=10.393598
# [PSO] iter 41/200 gbest=9.845065
# [PSO] iter 61/200 gbest=9.466028
# [PSO] iter 81/200 gbest=9.121608
# [PSO] iter 101/200 gbest=8.760432
# [PSO] iter 121/200 gbest=8.273262
# [PSO] iter 141/200 gbest=8.252457
# [PSO] iter 161/200 gbest=8.128534
# [PSO] iter 181/200 gbest=8.026458
# [PSO] iter 200/200 gbest=7.907138
#    gBest=7.9071 | Train MAE=7.9071 | Test MAE=8.2445
#
#  Run 9/10
# [PSO] iter 1/200 gbest=30.431322
# [PSO] iter 21/200 gbest=11.127056
# [PSO] iter 41/200 gbest=10.303065
# [PSO] iter 61/200 gbest=9.252406
# [PSO] iter 81/200 gbest=8.871932
# [PSO] iter 101/200 gbest=8.644589
# [PSO] iter 121/200 gbest=8.136843
# [PSO] iter 141/200 gbest=8.040541
# [PSO] iter 161/200 gbest=7.984922
# [PSO] iter 181/200 gbest=7.910290
# [PSO] iter 200/200 gbest=7.847048
#    gBest=7.8470 | Train MAE=7.8470 | Test MAE=8.4648
#
#  Run 10/10
# [PSO] iter 1/200 gbest=29.801875
# [PSO] iter 21/200 gbest=10.498688
# [PSO] iter 41/200 gbest=10.140562
# [PSO] iter 61/200 gbest=9.322307
# [PSO] iter 81/200 gbest=9.232413
# [PSO] iter 101/200 gbest=8.907527
# [PSO] iter 121/200 gbest=8.136199
# [PSO] iter 141/200 gbest=8.121352
# [PSO] iter 161/200 gbest=8.000136
# [PSO] iter 181/200 gbest=7.971483
# [PSO] iter 200/200 gbest=7.943588
#    gBest=7.9436 | Train MAE=7.9436 | Test MAE=8.2756
#
# ======== EXPERIMENT SUMMARY (Mean ± SD) ========
# Number of Runs:   10
# ANN Architecture: 16(relu) → 8(relu)
# PSO Config:       swarm=40, iter=200, αlpha=0.72, beta=1.49, gamma=1.49, bounds=(-5.0, 5.0)
# Average gBest:    7.6981 ± 0.2258
# Average Train MAE:7.6981 ± 0.2258
# Average Test MAE: 8.1395 ± 0.1814
# ===================================================
# Generating averaged plots across runs...
# visualization completed.

# %% [markdown]
# #### **ANN - 3 Hidden Layers**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 32,  "activation": "relu"}, #Hidden Layer 1
        {"units": 16,  "activation": "relu"}, #Hidden Layer 2
        {"units": 8,  "activation": "relu"}, #Hidden Layer 3
    ],
    output_dim=1,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)
# Out:
# ======== EXPERIMENTAL PIPELINE (10 RUNS) ========
#
#  Run 1/10
# [PSO] iter 1/200 gbest=415.669511
# [PSO] iter 21/200 gbest=13.007150
# [PSO] iter 41/200 gbest=11.214069
# [PSO] iter 61/200 gbest=10.964046
# [PSO] iter 81/200 gbest=10.360971
# [PSO] iter 101/200 gbest=10.087742
# [PSO] iter 121/200 gbest=9.520055
# [PSO] iter 141/200 gbest=9.045744
# [PSO] iter 161/200 gbest=8.867675
# [PSO] iter 181/200 gbest=8.615153
# [PSO] iter 200/200 gbest=8.603668
#    gBest=8.6037 | Train MAE=8.6037 | Test MAE=9.4868
#
#  Run 2/10
# [PSO] iter 1/200 gbest=166.211817
# [PSO] iter 21/200 gbest=12.093375
# [PSO] iter 41/200 gbest=11.423553
# [PSO] iter 61/200 gbest=10.540004
# [PSO] iter 81/200 gbest=10.155967
# [PSO] iter 101/200 gbest=10.065722
# [PSO] iter 121/200 gbest=9.988249
# [PSO] iter 141/200 gbest=9.877589
# [PSO] iter 161/200 gbest=9.383519
# [PSO] iter 181/200 gbest=9.125190
# [PSO] iter 200/200 gbest=9.083068
#    gBest=9.0831 | Train MAE=9.0831 | Test MAE=9.4655
#
#  Run 3/10
# [PSO] iter 1/200 gbest=75.804344
# [PSO] iter 21/200 gbest=11.942612
# [PSO] iter 41/200 gbest=10.444470
# [PSO] iter 61/200 gbest=9.901356
# [PSO] iter 81/200 gbest=9.231097
# [PSO] iter 101/200 gbest=9.128743
# [PSO] iter 121/200 gbest=8.520724
# [PSO] iter 141/200 gbest=8.358562
# [PSO] iter 161/200 gbest=8.297769
# [PSO] iter 181/200 gbest=8.222769
# [PSO] iter 200/200 gbest=7.839088
#    gBest=7.8391 | Train MAE=7.8391 | Test MAE=8.9800
#
#  Run 4/10
# [PSO] iter 1/200 gbest=470.158184
# [PSO] iter 21/200 gbest=14.210742
# [PSO] iter 41/200 gbest=11.143676
# [PSO] iter 61/200 gbest=9.454186
# [PSO] iter 81/200 gbest=9.412814
# [PSO] iter 101/200 gbest=9.412589
# [PSO] iter 121/200 gbest=8.898767
# [PSO] iter 141/200 gbest=8.754674
# [PSO] iter 161/200 gbest=8.272662
# [PSO] iter 181/200 gbest=8.096471
# [PSO] iter 200/200 gbest=7.811315
#    gBest=7.8113 | Train MAE=7.8113 | Test MAE=8.3341
#
#  Run 5/10
# [PSO] iter 1/200 gbest=172.070013
# [PSO] iter 21/200 gbest=12.015581
# [PSO] iter 41/200 gbest=11.881797
# [PSO] iter 61/200 gbest=11.027898
# [PSO] iter 81/200 gbest=9.491218
# [PSO] iter 101/200 gbest=9.151787
# [PSO] iter 121/200 gbest=9.151787
# [PSO] iter 141/200 gbest=9.142009
# [PSO] iter 161/200 gbest=9.137530

# %% [markdown]
# #### **Results & Discussion**
#
#
# This is our initial experiment used an ANN with two hidden layers which contains 16, 8 neurons with RELU activation and PSO configuration of 40 particles and 400 iterations. The model achieved a training MAE(mean absolute error) of 6.6270 and testing MAE 7.2031 indicating good generalisation with minimal overfitting. The PSO convergence curve showed a steep improvement in the early iterations followed by gradual stabilisation, suggesting effective exploration and convergence toward optimal network parameters. The small gap between training and testing MAE confirms that the network successfully captured the non-linear relationships within the concrete strength dataset. Overall, this result establishes a strong baseline, demonstrating that PSO can efficiently optimise ANN weights and biases for regression problems without gradient-based learning, while providing a stable and interpretable convergence pattern.
