# %% [markdown]
# ### **Experiment with different Activation functions**

# %% [markdown]
# #### **Project Path and imports**

# %%
import sys
from pathlib import Path
from src.train.pipeline import run_pipeline
from src.ann.config import ANNConfig
from src.pso.config import PSOConfig

# project root = parent of "notebooks"
PROJECT_ROOT = Path(__file__).resolve().parents[1] if "__file__" in globals() else Path.cwd().parents[0]

# Make sure root is on sys.path so we can import train, pso, etc.
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT
# Out:
# WindowsPath('C:/university/BC/F21BC-Coursework/src/notebooks/Task 5 - Experiment')

# %% [markdown]
# #### **PSO Configs- Static**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=40,
    iterations=200,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %% [markdown]
# #### **ANN -RELU**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 8,  "activation": "relu"},
    ],
    output_dim=1,
)

# %%
# Run training pipeline
run_pipeline(ann_config, pso_config,runs=10)
# Out:
# ======== EXPERIMENTAL PIPELINE (10 RUNS) ========
#
#  Run 1/10
# [PSO] iter 1/200 gbest=16.678508
# [PSO] iter 21/200 gbest=9.398003
# [PSO] iter 41/200 gbest=8.419444
# [PSO] iter 61/200 gbest=7.750600
# [PSO] iter 81/200 gbest=7.500321
# [PSO] iter 101/200 gbest=7.452744
# [PSO] iter 121/200 gbest=7.267638
# [PSO] iter 141/200 gbest=7.240041
# [PSO] iter 161/200 gbest=7.195039
# [PSO] iter 181/200 gbest=7.175987
# [PSO] iter 200/200 gbest=7.076087
#    gBest=7.0761 | Train MAE=7.0761 | Test MAE=7.7036
#
#  Run 2/10
# [PSO] iter 1/200 gbest=13.126945
# [PSO] iter 21/200 gbest=9.107244
# [PSO] iter 41/200 gbest=8.550662
# [PSO] iter 61/200 gbest=8.303314
# [PSO] iter 81/200 gbest=8.253049
# [PSO] iter 101/200 gbest=8.141389
# [PSO] iter 121/200 gbest=7.882019
# [PSO] iter 141/200 gbest=7.811734
# [PSO] iter 161/200 gbest=7.611050
# [PSO] iter 181/200 gbest=7.522576
# [PSO] iter 200/200 gbest=7.494024
#    gBest=7.4940 | Train MAE=7.4940 | Test MAE=8.0862
#
#  Run 3/10
# [PSO] iter 1/200 gbest=13.364043
# [PSO] iter 21/200 gbest=9.075834
# [PSO] iter 41/200 gbest=8.299367
# [PSO] iter 61/200 gbest=7.922979
# [PSO] iter 81/200 gbest=7.654787
# [PSO] iter 101/200 gbest=7.541890
# [PSO] iter 121/200 gbest=7.468880
# [PSO] iter 141/200 gbest=7.318924
# [PSO] iter 161/200 gbest=7.285121
# [PSO] iter 181/200 gbest=7.235531
# [PSO] iter 200/200 gbest=7.017537
#    gBest=7.0175 | Train MAE=7.0175 | Test MAE=7.7963
#
#  Run 4/10
# [PSO] iter 1/200 gbest=16.377014
# [PSO] iter 21/200 gbest=9.999087
# [PSO] iter 41/200 gbest=9.035266
# [PSO] iter 61/200 gbest=8.550376
# [PSO] iter 81/200 gbest=8.433169
# [PSO] iter 101/200 gbest=8.351118
# [PSO] iter 121/200 gbest=8.133294
# [PSO] iter 141/200 gbest=7.688338
# [PSO] iter 161/200 gbest=7.577592
# [PSO] iter 181/200 gbest=7.509672
# [PSO] iter 200/200 gbest=7.497279
#    gBest=7.4973 | Train MAE=7.4973 | Test MAE=8.0407
#
#  Run 5/10
# [PSO] iter 1/200 gbest=14.443404
# [PSO] iter 21/200 gbest=10.063627
# [PSO] iter 41/200 gbest=8.918015
# [PSO] iter 61/200 gbest=8.438920
# [PSO] iter 81/200 gbest=8.285833
# [PSO] iter 101/200 gbest=8.157436
# [PSO] iter 121/200 gbest=8.126667
# [PSO] iter 141/200 gbest=8.101153
# [PSO] iter 161/200 gbest=8.064524
# [PSO] iter 181/200 gbest=7.978053
# [PSO] iter 200/200 gbest=7.849593
#    gBest=7.8496 | Train MAE=7.8496 | Test MAE=8.3133
#
#  Run 6/10
# [PSO] iter 1/200 gbest=14.870347
# [PSO] iter 21/200 gbest=8.935602
# [PSO] iter 41/200 gbest=8.145252
# [PSO] iter 61/200 gbest=7.937031
# [PSO] iter 81/200 gbest=7.782650
# [PSO] iter 101/200 gbest=7.627353
# [PSO] iter 121/200 gbest=7.627353
# [PSO] iter 141/200 gbest=7.576597
# [PSO] iter 161/200 gbest=7.566379
# [PSO] iter 181/200 gbest=7.472553
# [PSO] iter 200/200 gbest=7.355958
#    gBest=7.3560 | Train MAE=7.3560 | Test MAE=7.8907
#
#  Run 7/10
# [PSO] iter 1/200 gbest=13.469853
# [PSO] iter 21/200 gbest=8.934372
# [PSO] iter 41/200 gbest=8.418510
# [PSO] iter 61/200 gbest=8.103072
# [PSO] iter 81/200 gbest=7.767582
# [PSO] iter 101/200 gbest=7.531561
# [PSO] iter 121/200 gbest=7.379032
# [PSO] iter 141/200 gbest=7.184260
# [PSO] iter 161/200 gbest=7.138503
# [PSO] iter 181/200 gbest=7.051405
# [PSO] iter 200/200 gbest=6.991823
#    gBest=6.9918 | Train MAE=6.9918 | Test MAE=7.6996
#
#  Run 8/10
# [PSO] iter 1/200 gbest=12.546532
# [PSO] iter 21/200 gbest=9.882879
# [PSO] iter 41/200 gbest=8.815661
# [PSO] iter 61/200 gbest=8.545918
# [PSO] iter 81/200 gbest=8.423052
# [PSO] iter 101/200 gbest=8.287128
# [PSO] iter 121/200 gbest=8.124144
# [PSO] iter 141/200 gbest=7.971738
# [PSO] iter 161/200 gbest=7.929680
# [PSO] iter 181/200 gbest=7.838688
# [PSO] iter 200/200 gbest=7.812064
#    gBest=7.8121 | Train MAE=7.8121 | Test MAE=8.2269
#
#  Run 9/10
# [PSO] iter 1/200 gbest=15.959738
# [PSO] iter 21/200 gbest=9.849469
# [PSO] iter 41/200 gbest=8.874416
# [PSO] iter 61/200 gbest=8.494149
# [PSO] iter 81/200 gbest=8.274748
# [PSO] iter 101/200 gbest=7.959974
# [PSO] iter 121/200 gbest=7.763215
# [PSO] iter 141/200 gbest=7.626297
# [PSO] iter 161/200 gbest=7.617834
# [PSO] iter 181/200 gbest=7.581861
# [PSO] iter 200/200 gbest=7.545390
#    gBest=7.5454 | Train MAE=7.5454 | Test MAE=8.0301
#
#  Run 10/10
# [PSO] iter 1/200 gbest=15.603383
# [PSO] iter 21/200 gbest=9.616526
# [PSO] iter 41/200 gbest=8.306971
# [PSO] iter 61/200 gbest=8.067451
# [PSO] iter 81/200 gbest=7.940218
# [PSO] iter 101/200 gbest=7.869153
# [PSO] iter 121/200 gbest=7.826421
# [PSO] iter 141/200 gbest=7.764110
# [PSO] iter 161/200 gbest=7.732380
# [PSO] iter 181/200 gbest=7.692445
# [PSO] iter 200/200 gbest=7.646071
#    gBest=7.6461 | Train MAE=7.6461 | Test MAE=7.9930
#
# ======== EXPERIMENT SUMMARY (Mean ± SD) ========
# Number of Runs:   10
# ANN Architecture: 8(relu)
# PSO Config:       swarm=40, iter=200, αlpha=0.72, beta=1.49, gamma=1.49, bounds=(-5.0, 5.0)
# Average gBest:    7.4286 ± 0.2972
# Average Train MAE:7.4286 ± 0.2972
# Average Test MAE: 7.9780 ± 0.1966
# ===================================================
# C:\university\BC\F21BC-Coursework\src\train\pipeline.py:170: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(rect=[1, 0, 1, 0.94])
# Generating averaged plots across runs...
# visualization completed.

# %% [markdown]
# #### **ANN-Tanh**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 8,  "activation": "tanh"},
    ],
    output_dim=1,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)
# Out:
# ======== EXPERIMENTAL PIPELINE (10 RUNS) ========
#
#  Run 1/10
# [PSO] iter 1/200 gbest=25.156849
# [PSO] iter 21/200 gbest=11.921007
# [PSO] iter 41/200 gbest=9.800642
# [PSO] iter 61/200 gbest=9.388541
# [PSO] iter 81/200 gbest=9.106377
# [PSO] iter 101/200 gbest=8.969148
# [PSO] iter 121/200 gbest=8.766285
# [PSO] iter 141/200 gbest=8.734348
# [PSO] iter 161/200 gbest=8.705469
# [PSO] iter 181/200 gbest=8.699986
# [PSO] iter 200/200 gbest=8.695009
#    gBest=8.6950 | Train MAE=8.6950 | Test MAE=9.0315
#
#  Run 2/10
# [PSO] iter 1/200 gbest=22.153635
# [PSO] iter 21/200 gbest=11.007320
# [PSO] iter 41/200 gbest=10.336126
# [PSO] iter 61/200 gbest=10.281514
# [PSO] iter 81/200 gbest=10.264924
# [PSO] iter 101/200 gbest=10.238352
# [PSO] iter 121/200 gbest=10.227668
# [PSO] iter 141/200 gbest=10.211754
# [PSO] iter 161/200 gbest=10.209171
# [PSO] iter 181/200 gbest=10.203887
# [PSO] iter 200/200 gbest=10.202445
#    gBest=10.2024 | Train MAE=10.2024 | Test MAE=10.9956
#
#  Run 3/10
# [PSO] iter 1/200 gbest=17.094512
# [PSO] iter 21/200 gbest=11.339390
# [PSO] iter 41/200 gbest=9.791267
# [PSO] iter 61/200 gbest=9.441304
# [PSO] iter 81/200 gbest=9.242339
# [PSO] iter 101/200 gbest=9.198497
# [PSO] iter 121/200 gbest=9.132851
# [PSO] iter 141/200 gbest=9.107749
# [PSO] iter 161/200 gbest=9.093294
# [PSO] iter 181/200 gbest=9.085725
# [PSO] iter 200/200 gbest=9.075493
#    gBest=9.0755 | Train MAE=9.0755 | Test MAE=9.3739
#
#  Run 4/10
# [PSO] iter 1/200 gbest=22.525818
# [PSO] iter 21/200 gbest=12.429429
# [PSO] iter 41/200 gbest=10.441788
# [PSO] iter 61/200 gbest=10.170385
# [PSO] iter 81/200 gbest=10.091913
# [PSO] iter 101/200 gbest=10.040254
# [PSO] iter 121/200 gbest=9.998086
# [PSO] iter 141/200 gbest=9.975229
# [PSO] iter 161/200 gbest=9.974903
# [PSO] iter 181/200 gbest=9.974884
# [PSO] iter 200/200 gbest=9.972203
#    gBest=9.9722 | Train MAE=9.9722 | Test MAE=10.5977
#
#  Run 5/10
# [PSO] iter 1/200 gbest=15.318851
# [PSO] iter 21/200 gbest=11.167329
# [PSO] iter 41/200 gbest=10.063001
# [PSO] iter 61/200 gbest=9.550625
# [PSO] iter 81/200 gbest=9.046712
# [PSO] iter 101/200 gbest=8.819534
# [PSO] iter 121/200 gbest=8.721175
# [PSO] iter 141/200 gbest=8.671966
# [PSO] iter 161/200 gbest=8.620389
# [PSO] iter 181/200 gbest=8.604092
# [PSO] iter 200/200 gbest=8.594173
#    gBest=8.5942 | Train MAE=8.5942 | Test MAE=8.9127
#
#  Run 6/10
# [PSO] iter 1/200 gbest=20.034425
# [PSO] iter 21/200 gbest=12.258485
# [PSO] iter 41/200 gbest=10.577321
# [PSO] iter 61/200 gbest=10.126578
# [PSO] iter 81/200 gbest=9.901590
# [PSO] iter 101/200 gbest=9.687083
# [PSO] iter 121/200 gbest=9.308267
# [PSO] iter 141/200 gbest=9.183127
# [PSO] iter 161/200 gbest=9.083004
# [PSO] iter 181/200 gbest=9.005802
# [PSO] iter 200/200 gbest=8.922544
#    gBest=8.9225 | Train MAE=8.9225 | Test MAE=9.4284
#
#  Run 7/10
# [PSO] iter 1/200 gbest=18.266536
# [PSO] iter 21/200 gbest=11.349518
# [PSO] iter 41/200 gbest=9.941578
# [PSO] iter 61/200 gbest=9.187195
# [PSO] iter 81/200 gbest=9.106572
# [PSO] iter 101/200 gbest=8.998932
# [PSO] iter 121/200 gbest=8.966219
# [PSO] iter 141/200 gbest=8.945893
# [PSO] iter 161/200 gbest=8.909311
# [PSO] iter 181/200 gbest=8.895464
# [PSO] iter 200/200 gbest=8.888547
#    gBest=8.8885 | Train MAE=8.8885 | Test MAE=9.6525
#
#  Run 8/10
# [PSO] iter 1/200 gbest=24.052376
# [PSO] iter 21/200 gbest=11.353629
# [PSO] iter 41/200 gbest=9.905388
# [PSO] iter 61/200 gbest=9.590252
# [PSO] iter 81/200 gbest=9.149725
# [PSO] iter 101/200 gbest=8.996236
# [PSO] iter 121/200 gbest=8.856594
# [PSO] iter 141/200 gbest=8.821503
# [PSO] iter 161/200 gbest=8.777827
# [PSO] iter 181/200 gbest=8.772686
# [PSO] iter 200/200 gbest=8.767762
#    gBest=8.7678 | Train MAE=8.7678 | Test MAE=9.2320
#
#  Run 9/10
# [PSO] iter 1/200 gbest=24.340600
# [PSO] iter 21/200 gbest=11.819441
# [PSO] iter 41/200 gbest=9.983217
# [PSO] iter 61/200 gbest=9.390986
# [PSO] iter 81/200 gbest=9.043192
# [PSO] iter 101/200 gbest=8.898762
# [PSO] iter 121/200 gbest=8.746866
# [PSO] iter 141/200 gbest=8.675164
# [PSO] iter 161/200 gbest=8.592668
# [PSO] iter 181/200 gbest=8.575442
# [PSO] iter 200/200 gbest=8.532628
#    gBest=8.5326 | Train MAE=8.5326 | Test MAE=9.0035
#
#  Run 10/10
# [PSO] iter 1/200 gbest=20.121516
# [PSO] iter 21/200 gbest=10.414149
# [PSO] iter 41/200 gbest=9.565421
# [PSO] iter 61/200 gbest=9.317260
# [PSO] iter 81/200 gbest=9.186606
# [PSO] iter 101/200 gbest=9.098273
# [PSO] iter 121/200 gbest=9.073738
# [PSO] iter 141/200 gbest=9.058177
# [PSO] iter 161/200 gbest=9.055781
# [PSO] iter 181/200 gbest=9.053242
# [PSO] iter 200/200 gbest=9.046500
#    gBest=9.0465 | Train MAE=9.0465 | Test MAE=9.3985
#
# ======== EXPERIMENT SUMMARY (Mean ± SD) ========
# Number of Runs:   10
# ANN Architecture: 8(tanh)
# PSO Config:       swarm=40, iter=200, αlpha=0.72, beta=1.49, gamma=1.49, bounds=(-5.0, 5.0)
# Average gBest:    9.0697 ± 0.5384
# Average Train MAE:9.0697 ± 0.5384
# Average Test MAE: 9.5626 ± 0.6588
# ===================================================
# Generating averaged plots across runs...
# visualization completed.

# %% [markdown]
# #### **ANN - RELU + Tanh**

# %%
# ANN CONFIG
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 16, "activation": "tanh"},
        {"units": 8,  "activation": "relu"},
    ],
    output_dim=1,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)
# Out:
# ======== EXPERIMENTAL PIPELINE (10 RUNS) ========
#
#  Run 1/10
# [PSO] iter 1/200 gbest=20.908271
# [PSO] iter 21/200 gbest=11.730809
# [PSO] iter 41/200 gbest=10.941035
# [PSO] iter 61/200 gbest=10.809031
# [PSO] iter 81/200 gbest=10.466195
# [PSO] iter 101/200 gbest=10.007216
# [PSO] iter 121/200 gbest=9.482384
# [PSO] iter 141/200 gbest=9.214206
# [PSO] iter 161/200 gbest=9.002329
# [PSO] iter 181/200 gbest=8.826441
# [PSO] iter 200/200 gbest=8.777559
#    gBest=8.7776 | Train MAE=8.7776 | Test MAE=9.7786
#
#  Run 2/10
# [PSO] iter 1/200 gbest=24.406423
# [PSO] iter 21/200 gbest=12.186895
# [PSO] iter 41/200 gbest=11.396661
# [PSO] iter 61/200 gbest=10.935752
# [PSO] iter 81/200 gbest=10.046301
# [PSO] iter 101/200 gbest=9.679104
# [PSO] iter 121/200 gbest=9.361641
# [PSO] iter 141/200 gbest=9.326852
# [PSO] iter 161/200 gbest=9.255667
# [PSO] iter 181/200 gbest=9.187886
# [PSO] iter 200/200 gbest=9.133427
#    gBest=9.1334 | Train MAE=9.1334 | Test MAE=9.5848
#
#  Run 3/10
# [PSO] iter 1/200 gbest=23.879708
# [PSO] iter 21/200 gbest=12.698067
# [PSO] iter 41/200 gbest=11.482393
# [PSO] iter 61/200 gbest=11.347275
# [PSO] iter 81/200 gbest=11.035681
# [PSO] iter 101/200 gbest=10.782562
# [PSO] iter 121/200 gbest=10.454989
# [PSO] iter 141/200 gbest=10.264977
# [PSO] iter 161/200 gbest=9.983115
# [PSO] iter 181/200 gbest=9.890278
# [PSO] iter 200/200 gbest=9.591389
#    gBest=9.5914 | Train MAE=9.5914 | Test MAE=10.3304
#
#  Run 4/10
# [PSO] iter 1/200 gbest=21.839206
# [PSO] iter 21/200 gbest=12.614180
# [PSO] iter 41/200 gbest=11.390989
# [PSO] iter 61/200 gbest=10.810891
# [PSO] iter 81/200 gbest=10.302931
# [PSO] iter 101/200 gbest=9.795762
# [PSO] iter 121/200 gbest=9.359202
# [PSO] iter 141/200 gbest=9.155938
# [PSO] iter 161/200 gbest=9.146323
# [PSO] iter 181/200 gbest=9.130641
# [PSO] iter 200/200 gbest=9.025254
#    gBest=9.0253 | Train MAE=9.0253 | Test MAE=9.2528
#
#  Run 5/10
# [PSO] iter 1/200 gbest=20.170089
# [PSO] iter 21/200 gbest=11.964100
# [PSO] iter 41/200 gbest=11.147654
# [PSO] iter 61/200 gbest=11.052059
# [PSO] iter 81/200 gbest=10.596831
# [PSO] iter 101/200 gbest=10.516762
# [PSO] iter 121/200 gbest=10.396220
# [PSO] iter 141/200 gbest=10.380686
# [PSO] iter 161/200 gbest=10.295186
# [PSO] iter 181/200 gbest=10.157528
# [PSO] iter 200/200 gbest=10.120722
#    gBest=10.1207 | Train MAE=10.1207 | Test MAE=11.0347
#
#  Run 6/10
# [PSO] iter 1/200 gbest=21.155023
# [PSO] iter 21/200 gbest=11.942930
# [PSO] iter 41/200 gbest=10.547626
# [PSO] iter 61/200 gbest=9.888463
# [PSO] iter 81/200 gbest=8.994023
# [PSO] iter 101/200 gbest=8.941508
# [PSO] iter 121/200 gbest=8.774631
# [PSO] iter 141/200 gbest=8.730472
# [PSO] iter 161/200 gbest=8.669495
# [PSO] iter 181/200 gbest=8.582621

# %% [markdown]
# #### **Results & Discussion**
#
#
# This is our initial experiment used an ANN with two hidden layers which contains 16, 8 neurons with RELU activation and PSO configuration of 40 particles and 400 iterations. The model achieved a training MAE(mean absolute error) of 6.6270 and testing MAE 7.2031 indicating good generalisation with minimal overfitting. The PSO convergence curve showed a steep improvement in the early iterations followed by gradual stabilisation, suggesting effective exploration and convergence toward optimal network parameters. The small gap between training and testing MAE confirms that the network successfully captured the non-linear relationships within the concrete strength dataset. Overall, this result establishes a strong baseline, demonstrating that PSO can efficiently optimise ANN weights and biases for regression problems without gradient-based learning, while providing a stable and interpretable convergence pattern.
