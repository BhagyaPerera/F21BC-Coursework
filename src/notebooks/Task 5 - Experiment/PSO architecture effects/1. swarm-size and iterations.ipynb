# %% [markdown]
# ### **Experiment with different Swarm size and Iterations**

# %% [markdown]
# #### **Project Path and imports**

# %%
import sys
from pathlib import Path
from src.train.pipeline import run_pipeline
from src.ann.config import ANNConfig
from src.pso.config import PSOConfig

# project root = parent of "notebooks"
PROJECT_ROOT = Path(__file__).resolve().parents[1] if "__file__" in globals() else Path.cwd().parents[0]

# Make sure root is on sys.path so we can import train, pso, etc.
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %% [markdown]
# #### **ANN (static)**

# %%
# ANN CONFIG
ann_config = ANNConfig(
    input_dim=8,   # 8 features in dataset
    hidden_layers=[
        {"units": 32,  "activation": "relu"}, #Hidden Layer 1
        {"units": 16,  "activation": "relu"}, #Hidden Layer 2
        {"units": 8,  "activation": "relu"}, #Hidden Layer 3
    ],
    output_dim=1,
)

# %% [markdown]
# #### **PSO Configs- swarm size-10 Iteration-50**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=10,
    iterations=50,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %% [markdown]
# ##### **Train and Test evaluation**

# %%
# Run training pipeline
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **PSO- swarm size-20 Iteration-25**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=20,
    iterations=25,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **PSO- swarm size-25 Iteration-20**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=25,
    iterations=20,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %%
# Run training pipeline
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **PSO Swarm-size 50 iteration 10**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=50,
    iterations=10,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **PSO Swarm-size 100 iteration 5**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=100,
    iterations=5,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %%
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **PSO Swarm-size 250 iterations-2**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=250,
    iterations=2,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %%
# Run training pipeline
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **PSO Swarm-size 500 iteration 1**

# %%
# PSO CONFIG — baseline
pso_config = PSOConfig(
    swarm_size=500,
    iterations=1,
    alpha=0.72,
    beta=1.49,
    gamma=1.49,
    delta=0.0,
    e=1.0,
    bounds=(-5.0, 5.0),
    v_clamp=(-2.0, 2.0),
    k_informants=3,
    rewire_every=None,
    boundary_mode="clip",
    seed=None,
    minimize=True,
)

# %%
# Run training pipeline
run_pipeline(ann_config, pso_config,runs=10)

# %% [markdown]
# #### **Results & Discussion**
#
#
# This is our initial experiment used an ANN with two hidden layers which contains 16, 8 neurons with RELU activation and PSO configuration of 40 particles and 400 iterations. The model achieved a training MAE(mean absolute error) of 6.6270 and testing MAE 7.2031 indicating good generalisation with minimal overfitting. The PSO convergence curve showed a steep improvement in the early iterations followed by gradual stabilisation, suggesting effective exploration and convergence toward optimal network parameters. The small gap between training and testing MAE confirms that the network successfully captured the non-linear relationships within the concrete strength dataset. Overall, this result establishes a strong baseline, demonstrating that PSO can efficiently optimise ANN weights and biases for regression problems without gradient-based learning, while providing a stable and interpretable convergence pattern.
